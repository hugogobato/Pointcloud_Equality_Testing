# %% [markdown]
# # Phase 6 high-dimensional point-law shard 12 of 36 — phase6_highdim_extra_dense_thorough [thorough]
#
# **Predicted runtime: 62.5 minutes** (wall, N_WORKERS=2, 199 perms, all (14 incl SC-A), VR filtration).
# Tasks in shard: 20 (≤20 cap) → each task = 25 replications checkpointed to `results/phase6_highdim_extra_dense_thorough/`.
#
# This is **thorough / high-precision**. Full budget (500 reps, 199 perms, all candidates) for size/power gates and computation. Run only after pilot promising.
#
# **Fleet**: d=[10, 20, 40], n=[50, 500], preproc=['pca3', 'raw'], families=['covariance_shift', 'dense_same_support_density', 'dense_topology_rotated']
# Methods: all (14 incl SC-A). SC-A omitted. Rosenbaum only for n=50.
# Preproc `raw` vs `pca3` (pooled PCA to 3 dims, valid under H0). PCA-failure families use high-noise background.
#
# **Download**: at end of shard ONE zip is created (`/tmp/phase6_highdim_extra_dense_thorough_shardXX.zip`) containing all parquets in `results/phase6_highdim_extra_dense_thorough/` and downloaded via `google.colab.files.download` (avoids per-tab multi-download limit). Keep tab open until “Downloaded zip” prints. Then collect all downloaded zips locally, unzip into `results/phase6_highdim_extra_dense_thorough/` and run:
#
# ```
# python experiments/phase6_highdim_pointlaw_tournament.py --mode aggregate --input-dir results/phase6_highdim_extra_dense_thorough
# ```
#
# Design hash `401912b22817e1af` | FILTRATION=vr | seed_root=20260826

# %%
import os

SHARD_ID = 12
N_SHARDS = 36
FLEET_NAME = "phase6_highdim_extra_dense_thorough"
RESULTS_DIR = "results/phase6_highdim_extra_dense_thorough"
SEED_ROOT = 20260826
WALL_BUDGET_MIN = 450
N_WORKERS = 2
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"
print({"SHARD_ID": SHARD_ID, "N_SHARDS": N_SHARDS, "FLEET": FLEET_NAME, "WALL_BUDGET_MIN": WALL_BUDGET_MIN, "N_WORKERS": N_WORKERS})

# %%
import os, shutil, sys, subprocess
REPO_DIR = "/content/Pointcloud_Equality_Testing"
FLEET_NAME = "phase6_highdim_extra_dense_thorough"
RESULTS_DIR = "results/phase6_highdim_extra_dense_thorough"
if os.path.isdir(REPO_DIR):
    shutil.rmtree(REPO_DIR)
ret = os.system("git clone --depth 1 https://github.com/hugogobato/Pointcloud_Equality_Testing.git " + REPO_DIR)
print("clone exit", ret)
os.chdir(REPO_DIR)
ret = os.system("python -m pip install -q -e .")
print("pip install -e . exit", ret)
os.makedirs(RESULTS_DIR, exist_ok=True)
print("repo ready", REPO_DIR, "results", RESULTS_DIR)

# %%
# %%bash
# set -e
# pip install -q numpy scipy scikit-learn scikit-fda matplotlib networkx==3.4.2 gudhi pot ripser 2>&1 | tail -20
# pip install -q git+https://github.com/hugogobato/tcda_uq.git 2>&1 | tail -5
# echo '--- install done ---'
# python -c "import gudhi, sklearn, ripser; print('gudhi', gudhi.__version__)"

# %%
import os, sys
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"
sys.path.insert(0, "/content/Pointcloud_Equality_Testing")
import numpy as np
from experiments.phase6_highdim_pointlaw_tournament import make_cloud_pair_highdim, Cell
c0,c1 = make_cloud_pair_highdim("iid_null", 50, 50, seed=123, d=10)
print("cloud shapes", c0.shape, c1.shape)
from experiments.phase6_highdim_pointlaw_tournament import _run_one
cell = Cell(family="iid_null", n0=50, n1=50, m=25, d=10, preproc="raw", role="gating_null", description="test")
rows = _run_one((cell, 0, ("PointMMD-Gaussian","RawBlockMMD","SC-B"), 19, None))
print("smoke", [(r["method"], r["status"], round(float(r["pvalue"]),3)) for r in rows])
print("imports OK |", os.cpu_count(), "CPUs")

# %%
import os, json, time, glob, shutil
from pathlib import Path
import pandas as pd
from experiments.phase6_highdim_pointlaw_tournament import Cell, run_shard, DESIGN_HASH

SHARD_ID = 12
N_SHARDS = 36
FLEET_NAME = "phase6_highdim_extra_dense_thorough"
RESULTS_DIR = "results/phase6_highdim_extra_dense_thorough"
SEED_ROOT = 20260826
WALL_BUDGET_MIN = 450
N_WORKERS = 2
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"
print({"SHARD_ID": SHARD_ID, "N_SHARDS": N_SHARDS, "FLEET": FLEET_NAME, "WALL_BUDGET_MIN": WALL_BUDGET_MIN, "N_WORKERS": N_WORKERS, "DESIGN_HASH": DESIGN_HASH})

TASKS = [
  {
    "task_id": "dense_same_support_density_n500_n1500_m25_d10_preproc_raw_rep300_324",
    "cell_id": "dense_same_support_density_n500_n1500_m25_d10_preproc_raw",
    "family": "dense_same_support_density",
    "n0": 500,
    "n1": 500,
    "m": 25,
    "d": 10,
    "preproc": "raw",
    "role": "unknown",
    "description": "dense_same_support_density",
    "rep_start": 300,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block"
    ],
    "predicted_seconds": 450.0
  },
  {
    "task_id": "dense_same_support_density_n500_n1500_m25_d20_preproc_raw_rep200_224",
    "cell_id": "dense_same_support_density_n500_n1500_m25_d20_preproc_raw",
    "family": "dense_same_support_density",
    "n0": 500,
    "n1": 500,
    "m": 25,
    "d": 20,
    "preproc": "raw",
    "role": "unknown",
    "description": "dense_same_support_density",
    "rep_start": 200,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block"
    ],
    "predicted_seconds": 450.0
  },
  {
    "task_id": "dense_same_support_density_n500_n1500_m25_d40_preproc_raw_rep100_124",
    "cell_id": "dense_same_support_density_n500_n1500_m25_d40_preproc_raw",
    "family": "dense_same_support_density",
    "n0": 500,
    "n1": 500,
    "m": 25,
    "d": 40,
    "preproc": "raw",
    "role": "unknown",
    "description": "dense_same_support_density",
    "rep_start": 100,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block"
    ],
    "predicted_seconds": 450.0
  },
  {
    "task_id": "dense_topology_rotated_n500_n1500_m25_d10_preproc_raw_rep0_24",
    "cell_id": "dense_topology_rotated_n500_n1500_m25_d10_preproc_raw",
    "family": "dense_topology_rotated",
    "n0": 500,
    "n1": 500,
    "m": 25,
    "d": 10,
    "preproc": "raw",
    "role": "unknown",
    "description": "dense_topology_rotated",
    "rep_start": 0,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block"
    ],
    "predicted_seconds": 450.0
  },
  {
    "task_id": "dense_topology_rotated_n500_n1500_m25_d10_preproc_pca3_rep400_424",
    "cell_id": "dense_topology_rotated_n500_n1500_m25_d10_preproc_pca3",
    "family": "dense_topology_rotated",
    "n0": 500,
    "n1": 500,
    "m": 25,
    "d": 10,
    "preproc": "pca3",
    "role": "unknown",
    "description": "dense_topology_rotated",
    "rep_start": 400,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block"
    ],
    "predicted_seconds": 450.0
  },
  {
    "task_id": "dense_topology_rotated_n500_n1500_m25_d20_preproc_pca3_rep300_324",
    "cell_id": "dense_topology_rotated_n500_n1500_m25_d20_preproc_pca3",
    "family": "dense_topology_rotated",
    "n0": 500,
    "n1": 500,
    "m": 25,
    "d": 20,
    "preproc": "pca3",
    "role": "unknown",
    "description": "dense_topology_rotated",
    "rep_start": 300,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block"
    ],
    "predicted_seconds": 450.0
  },
  {
    "task_id": "dense_topology_rotated_n500_n1500_m25_d40_preproc_pca3_rep200_224",
    "cell_id": "dense_topology_rotated_n500_n1500_m25_d40_preproc_pca3",
    "family": "dense_topology_rotated",
    "n0": 500,
    "n1": 500,
    "m": 25,
    "d": 40,
    "preproc": "pca3",
    "role": "unknown",
    "description": "dense_topology_rotated",
    "rep_start": 200,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block"
    ],
    "predicted_seconds": 450.0
  },
  {
    "task_id": "covariance_shift_n500_n1500_m25_d10_preproc_pca3_rep100_124",
    "cell_id": "covariance_shift_n500_n1500_m25_d10_preproc_pca3",
    "family": "covariance_shift",
    "n0": 500,
    "n1": 500,
    "m": 25,
    "d": 10,
    "preproc": "pca3",
    "role": "unknown",
    "description": "covariance_shift",
    "rep_start": 100,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block"
    ],
    "predicted_seconds": 450.0
  },
  {
    "task_id": "covariance_shift_n500_n1500_m25_d20_preproc_pca3_rep0_24",
    "cell_id": "covariance_shift_n500_n1500_m25_d20_preproc_pca3",
    "family": "covariance_shift",
    "n0": 500,
    "n1": 500,
    "m": 25,
    "d": 20,
    "preproc": "pca3",
    "role": "unknown",
    "description": "covariance_shift",
    "rep_start": 0,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block"
    ],
    "predicted_seconds": 450.0
  },
  {
    "task_id": "covariance_shift_n500_n1500_m25_d40_preproc_raw_rep400_424",
    "cell_id": "covariance_shift_n500_n1500_m25_d40_preproc_raw",
    "family": "covariance_shift",
    "n0": 500,
    "n1": 500,
    "m": 25,
    "d": 40,
    "preproc": "raw",
    "role": "unknown",
    "description": "covariance_shift",
    "rep_start": 400,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block"
    ],
    "predicted_seconds": 450.0
  },
  {
    "task_id": "dense_same_support_density_n50_n150_m25_d10_preproc_raw_rep300_324",
    "cell_id": "dense_same_support_density_n50_n150_m25_d10_preproc_raw",
    "family": "dense_same_support_density",
    "n0": 50,
    "n1": 50,
    "m": 25,
    "d": 10,
    "preproc": "raw",
    "role": "unknown",
    "description": "dense_same_support_density",
    "rep_start": 300,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block",
      "Rosenbaum-CrossMatch"
    ],
    "predicted_seconds": 150.0
  },
  {
    "task_id": "dense_same_support_density_n50_n150_m25_d20_preproc_raw_rep200_224",
    "cell_id": "dense_same_support_density_n50_n150_m25_d20_preproc_raw",
    "family": "dense_same_support_density",
    "n0": 50,
    "n1": 50,
    "m": 25,
    "d": 20,
    "preproc": "raw",
    "role": "unknown",
    "description": "dense_same_support_density",
    "rep_start": 200,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block",
      "Rosenbaum-CrossMatch"
    ],
    "predicted_seconds": 150.0
  },
  {
    "task_id": "dense_same_support_density_n50_n150_m25_d40_preproc_raw_rep100_124",
    "cell_id": "dense_same_support_density_n50_n150_m25_d40_preproc_raw",
    "family": "dense_same_support_density",
    "n0": 50,
    "n1": 50,
    "m": 25,
    "d": 40,
    "preproc": "raw",
    "role": "unknown",
    "description": "dense_same_support_density",
    "rep_start": 100,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block",
      "Rosenbaum-CrossMatch"
    ],
    "predicted_seconds": 150.0
  },
  {
    "task_id": "dense_topology_rotated_n50_n150_m25_d10_preproc_raw_rep0_24",
    "cell_id": "dense_topology_rotated_n50_n150_m25_d10_preproc_raw",
    "family": "dense_topology_rotated",
    "n0": 50,
    "n1": 50,
    "m": 25,
    "d": 10,
    "preproc": "raw",
    "role": "unknown",
    "description": "dense_topology_rotated",
    "rep_start": 0,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block",
      "Rosenbaum-CrossMatch"
    ],
    "predicted_seconds": 150.0
  },
  {
    "task_id": "dense_topology_rotated_n50_n150_m25_d10_preproc_pca3_rep400_424",
    "cell_id": "dense_topology_rotated_n50_n150_m25_d10_preproc_pca3",
    "family": "dense_topology_rotated",
    "n0": 50,
    "n1": 50,
    "m": 25,
    "d": 10,
    "preproc": "pca3",
    "role": "unknown",
    "description": "dense_topology_rotated",
    "rep_start": 400,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block",
      "Rosenbaum-CrossMatch"
    ],
    "predicted_seconds": 150.0
  },
  {
    "task_id": "dense_topology_rotated_n50_n150_m25_d20_preproc_pca3_rep300_324",
    "cell_id": "dense_topology_rotated_n50_n150_m25_d20_preproc_pca3",
    "family": "dense_topology_rotated",
    "n0": 50,
    "n1": 50,
    "m": 25,
    "d": 20,
    "preproc": "pca3",
    "role": "unknown",
    "description": "dense_topology_rotated",
    "rep_start": 300,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block",
      "Rosenbaum-CrossMatch"
    ],
    "predicted_seconds": 150.0
  },
  {
    "task_id": "dense_topology_rotated_n50_n150_m25_d40_preproc_pca3_rep200_224",
    "cell_id": "dense_topology_rotated_n50_n150_m25_d40_preproc_pca3",
    "family": "dense_topology_rotated",
    "n0": 50,
    "n1": 50,
    "m": 25,
    "d": 40,
    "preproc": "pca3",
    "role": "unknown",
    "description": "dense_topology_rotated",
    "rep_start": 200,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block",
      "Rosenbaum-CrossMatch"
    ],
    "predicted_seconds": 150.0
  },
  {
    "task_id": "covariance_shift_n50_n150_m25_d10_preproc_pca3_rep100_124",
    "cell_id": "covariance_shift_n50_n150_m25_d10_preproc_pca3",
    "family": "covariance_shift",
    "n0": 50,
    "n1": 50,
    "m": 25,
    "d": 10,
    "preproc": "pca3",
    "role": "unknown",
    "description": "covariance_shift",
    "rep_start": 100,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block",
      "Rosenbaum-CrossMatch"
    ],
    "predicted_seconds": 150.0
  },
  {
    "task_id": "covariance_shift_n50_n150_m25_d20_preproc_pca3_rep0_24",
    "cell_id": "covariance_shift_n50_n150_m25_d20_preproc_pca3",
    "family": "covariance_shift",
    "n0": 50,
    "n1": 50,
    "m": 25,
    "d": 20,
    "preproc": "pca3",
    "role": "unknown",
    "description": "covariance_shift",
    "rep_start": 0,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block",
      "Rosenbaum-CrossMatch"
    ],
    "predicted_seconds": 150.0
  },
  {
    "task_id": "covariance_shift_n50_n150_m25_d40_preproc_raw_rep400_424",
    "cell_id": "covariance_shift_n50_n150_m25_d40_preproc_raw",
    "family": "covariance_shift",
    "n0": 50,
    "n1": 50,
    "m": 25,
    "d": 40,
    "preproc": "raw",
    "role": "unknown",
    "description": "covariance_shift",
    "rep_start": 400,
    "replications": 25,
    "n_permutations": 199,
    "candidates": [
      "PointMMD-Gaussian",
      "PointMMD-Gaussian-median",
      "EnergyDistance",
      "FriedmanRafsky-MST",
      "Schilling-kNN-k1",
      "RawBlockMMD",
      "SC-B",
      "HybridBlockMMD-a0.50",
      "Schilling-kNN-k5",
      "Schilling-kNN-k10",
      "SlicedWasserstein",
      "ClassifierTwoSampleTest-logistic",
      "ClassifierTwoSampleTest-rf",
      "SC-A-Block",
      "Rosenbaum-CrossMatch"
    ],
    "predicted_seconds": 150.0
  }
]

os.makedirs(RESULTS_DIR, exist_ok=True)

t0 = time.time()
skipped = 0
ran = 0
for idx, task in enumerate(TASKS):
    print(f"\n=== Task {idx+1}/{len(TASKS)} {task['task_id']} ({task['n_permutations']} perms, {task['replications']} reps) ===")
    cell = Cell(family=task["family"], n0=task["n0"], n1=task["n1"], m=task["m"], d=task["d"], preproc=task["preproc"], role=task["role"], description=task["description"])
    out = os.path.join(RESULTS_DIR, f"phase6_highdim_{cell.cell_id}_rep{task['rep_start']}_{task['rep_start']+task['replications']-1}.parquet")
    if os.path.exists(out):
        # quick integrity check: can read?
        try:
            import pandas as pd
            df = pd.read_parquet(out)
            if len(df) > 0:
                print(f"  -> Skipping, already exists: {out} ({len(df)} rows)")
                skipped += 1
                continue
        except Exception as e:
            print(f"  -> Existing file unreadable, will rerun: {e}")
    # checkpoint every 25 reps if task larger than 25 — run_shard does it internally via single file
    run_shard(cell, rep_start=task["rep_start"], replications=task["replications"], n_permutations=task["n_permutations"], candidates=task["candidates"], workers=N_WORKERS, cache_dir=None, output=out)
    ran += 1
    print(f"  -> done {out}")
    print(f"--- {time.time()-t0:.0f}s elapsed, {idx+1}/{len(TASKS)} tasks done (ran {ran}, skipped {skipped}) ---")
    # Optional: show partial zip progress but do NOT download per-task (hits browser limit)

print(f"\nShard {SHARD_ID} tasks done in {time.time()-t0:.0f}s (ran {ran}, skipped {skipped})")
# Create single zip for download (one download per tab)
import shutil, glob, os
parquets = sorted(glob.glob(os.path.join(RESULTS_DIR, "*.parquet")))
print(f"Shard produced {len(parquets)} parquets in {RESULTS_DIR}")
zip_base = f"/tmp/{FLEET_NAME}_shard{SHARD_ID:02d}"
# make_archive expects base without extension, root_dir is RESULTS_DIR's parent but we want archive containing files flat
# We'll create zip with files flat via shutil.make_archive from RESULTS_DIR
# Use temporary staging: archive the RESULTS_DIR folder
try:
    # Remove old zip if exists
    if os.path.exists(zip_base + ".zip"):
        os.remove(zip_base + ".zip")
    shutil.make_archive(zip_base, "zip", RESULTS_DIR)
    zip_path = zip_base + ".zip"
    sz = os.path.getsize(zip_path) / 1e6
    print(f"Archive created: {zip_path} ({sz:.1f} MB) with {len(parquets)} files")
    try:
        from google.colab import files
        files.download(zip_path)
        print("Downloaded zip:", zip_path)
    except Exception as e:
        print("(Not on Colab / download skipped - manual download needed):", e)
        print("If on Colab, run: from google.colab import files; files.download('"+zip_path+"')")
    print("Files kept in", RESULTS_DIR, "and", zip_path)
except Exception as e:
    print("Zip creation failed:", e)
    # fallback: try to download individual files if zip fails (but will hit limit)
    print("Parquets:", parquets[:5])

try:
    from google.colab import files
    files.download(zip_path)
    print("Downloaded:", zip_path)
except Exception as e:
    print("(Not on Colab / download skipped):", e)
print("Done.")
